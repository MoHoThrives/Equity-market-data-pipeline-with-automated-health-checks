# %%
import yfinance as yf

# %%
ticker_list = ['MSFT', 'AAPL', 'GOOG', 'NVDA', 'AMD']

# %%
df = tickers.download(ticker_list, period='1mo')
# Out:
# [*********************100%***********************]  5 of 5 completed

# %%
type(df)
# Out:
# pandas.DataFrame
